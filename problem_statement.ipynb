# %% [markdown]
# ## Bike Sharing Dataset Data Set
#
# https://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset
#
# Abstract: This dataset contains the hourly and daily count of rental bikes between years 2011 and 2012 in Capital bikeshare system with the corresponding weather and seasonal information.
#
# ### Data Set Characteristics:
#
# ### Univariate
#
# ##### Number of Instances: 17389
# ##### Area: Social
# ##### Attribute Characteristics: Integer, Real
# ##### Number of Attributes: 16
# ##### Date Donated 2013-12-20
# ##### Associated Tasks: Regression
# ##### Missing Values? N/A
#
# ### Source:
#
# Hadi Fanaee-T
#
# Laboratory of Artificial Intelligence and Decision Support (LIAAD), University of Porto
# INESC Porto, Campus da FEUP
# Rua Dr. Roberto Frias, 378
# 4200 - 465 Porto, Portugal
#
#
# #### Original Source: http://capitalbikeshare.com/system-data
# #### Weather Information: http://www.freemeteo.com
# #### Holiday Schedule: http://dchr.dc.gov/page/holiday-schedule
#
#
# #### Data Set Information:
#
# Bike sharing systems are new generation of traditional bike rentals where whole process from membership, rental and return back has become automatic. Through these systems, user is able to easily rent a bike from a particular position and return back at another position. Currently, there are about over 500 bike-sharing programs around the world which is composed of over 500 thousands bicycles. Today, there exists great interest in these systems due to their important role in traffic, environmental and health issues.
#
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by these systems make them attractive for the research. Opposed to other transport services such as bus or subway, the duration of travel, departure and arrival position is explicitly recorded in these systems. This feature turns bike sharing system into a virtual sensor network that can be used for sensing mobility in the city. Hence, it is expected that most of important events in the city could be detected via monitoring these data.
#
# ### Objective - Regression:
#
# Predication of bike rental count hourly or daily based on the environmental and seasonal settings.
#
# #### Attribute Information:
#
# Both hour.csv and day.csv have the following fields, except hr which is not available in day.csv
#
# We will use hour.csv, the file containing bike sharing counts aggregated on hourly basis.
# Records: 17379 hours
#
# - instant: record index
# - dteday : date
# - season : season (1:springer, 2:summer, 3:fall, 4:winter)
# - yr : year (0: 2011, 1:2012)
# - mnth : month ( 1 to 12)
# - hr : hour (0 to 23)
# - holiday : weather day is holiday or not (extracted from [Web Link])
# - weekday : day of the week
# - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# + weathersit :
# - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp : Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39 (only in hourly scale)
# - atemp: Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale)
# - hum: Normalized humidity. The values are divided to 100 (max)
# - windspeed: Normalized wind speed. The values are divided to 67 (max)
# - casual: count of casual users
# - registered: count of registered users
# - cnt: count of total rental bikes including both casual and registered
#
#
# ### Relevant Papers:
#
# Fanaee-T, Hadi, and Gama, Joao, 'Event labeling combining ensemble detectors and background knowledge', Progress in Artificial Intelligence (2013): pp. 1-15, Springer Berlin Heidelberg, doi:10.1007/s13748-013-0040-3.
#
#
# ### Citation Request:
#
# Fanaee-T, Hadi, and Gama, Joao, 'Event labeling combining ensemble detectors and background knowledge', Progress in Artificial Intelligence (2013): pp. 1-15, Springer Berlin Heidelberg, doi:10.1007/s13748-013-0040-3.
#
# @article{
# year={2013},
# issn={2192-6352},
# journal={Progress in Artificial Intelligence},
# doi={10.1007/s13748-013-0040-3},
# title={Event labeling combining ensemble detectors and background knowledge},
# url={[Web Link]},
# publisher={Springer Berlin Heidelberg},
# keywords={Event labeling; Event detection; Ensemble learning; Background knowledge},
# author={Fanaee-T, Hadi and Gama, Joao},
# pages={1-15}
# }

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('hour.csv',index_col=0)
df.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
df.nunique()
# Out:
# instant       17379
# dteday          731
# season            4
# yr                2
# mnth             12
# hr               24
# holiday           2
# weekday           7
# workingday        2
# weathersit        4
# temp             50
# atemp            65
# hum              89
# windspeed        30
# casual          322
# registered      776
# cnt             869
# dtype: int64

# %%
df.shape
# Out:
# (17379, 17)

# %%
df.describe().T
# Out:
#               count         mean          std   min        25%        50%  \
# instant     17379.0  8690.000000  5017.029500  1.00  4345.5000  8690.0000
# season      17379.0     2.501640     1.106918  1.00     2.0000     3.0000
# yr          17379.0     0.502561     0.500008  0.00     0.0000     1.0000
# mnth        17379.0     6.537775     3.438776  1.00     4.0000     7.0000
# hr          17379.0    11.546752     6.914405  0.00     6.0000    12.0000
# holiday     17379.0     0.028770     0.167165  0.00     0.0000     0.0000
# weekday     17379.0     3.003683     2.005771  0.00     1.0000     3.0000
# workingday  17379.0     0.682721     0.465431  0.00     0.0000     1.0000
# weathersit  17379.0     1.425283     0.639357  1.00     1.0000     1.0000
# temp        17379.0     0.496987     0.192556  0.02     0.3400     0.5000
# atemp       17379.0     0.475775     0.171850  0.00     0.3333     0.4848
# hum         17379.0     0.627229     0.192930  0.00     0.4800     0.6300
# ...

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
a=df.groupby('yr')['cnt'].sum()
print(a)
b=df[df['yr']==0].shape
c=df[df['yr']==1].shape
print(b)
print(c)
#Data points in 2011 and 2012 are almost equal
# Out:
# yr
# 0    1243103
# 1    2049576
# Name: cnt, dtype: int64
# (8645, 16)
# (8734, 16)

# %%
sns.barplot(a.index,a)
#Rental bike pickup has increased in 2012 compared to 2011

# %%
b=df.groupby('yr')['casual'].sum()
print(b)

sns.barplot(b.index,b)
# Out:
# yr
# 0    247252
# 1    372765
# Name: casual, dtype: int64

# %%
r=df.groupby('yr')['registered'].sum()
print(r)

sns.barplot(r.index,r)
# Out:
# yr
# 0     995851
# 1    1676811
# Name: registered, dtype: int64

# %%
m=df.groupby('mnth')['cnt'].sum()
print(m)
plt.figure(figsize=(15,5))
sns.barplot(m.index,m)
#Bike pick up is more in the months of 5,6,7,8 and 9
# Out:
# mnth
# 1     134933
# 2     151352
# 3     228920
# 4     269094
# 5     331686
# 6     346342
# 7     344948
# 8     351194
# 9     345991
# 10    322352
# 11    254831
# 12    211036
# Name: cnt, dtype: int64

# %%
m1=df.groupby('mnth')['casual'].sum()
print(m1)
plt.figure(figsize=(15,5))
sns.barplot(m1.index,m1)
#Bike pick up is more in the months of 5,6,7,8 and 9
# Out:
# mnth
# 1     12042
# 2     14963
# 3     44444
# 4     60802
# 5     75285
# 6     73906
# 7     78157
# 8     72039
# 9     70323
# 10    59760
# 11    36603
# 12    21693
# Name: casual, dtype: int64

# %%
m2=df.groupby('mnth')['registered'].sum()
print(m2)
plt.figure(figsize=(15,5))
sns.barplot(m2.index,m2)
#Bike pick up is more in the months of 5,6,7,8 and 9
# Out:
# mnth
# 1     122891
# 2     136389
# 3     184476
# 4     208292
# 5     256401
# 6     272436
# 7     266791
# 8     279155
# 9     275668
# 10    262592
# 11    218228
# 12    189343
# Name: registered, dtype: int64

# %%
h1=df.groupby('hr')['cnt'].sum()
print(h1)
plt.figure(figsize=(15,5))
sns.barplot(h1.index,h1)
#Bike rental is more in morning 8 o clock, evening 4 o clock, 5 o clock, 6 o clock and 7 o clock
# Out:
# hr
# 0      39130
# 1      24164
# 2      16352
# 3       8174
# 4       4428
# 5      14261
# 6      55132
# 7     154171
# 8     261001
# 9     159438
# 10    126257
# 11    151320
# 12    184414
# 13    184919
# 14    175652
# 15    183149
# 16    227748
# 17    336860
# 18    309772
# 19    226789
# 20    164550
# 21    125445
# 22     95612
# 23     63941
# Name: cnt, dtype: int64

# %%
h2=df.groupby('hr')['casual'].sum()
print(h2)
plt.figure(figsize=(15,5))
sns.barplot(h2.index,h2)
#More bikes are rented by Casual users from morning 10 0 clock to evening 5 o clock
# Out:
# hr
# 0      7375
# 1      4709
# 2      3412
# 3      1893
# 4       874
# 5      1012
# 6      3017
# 7      8037
# 8     15761
# 9     22458
# 10    33789
# 11    43286
# 12    49718
# 13    52713
# 14    55089
# 15    54606
# 16    53834
# 17    54220
# 18    44496
# 19    35505
# 20    26378
# 21    20570
# 22    16200
# 23    11065
# Name: casual, dtype: int64

# %%
h3=df.groupby('hr')['registered'].sum()
print(h3)
plt.figure(figsize=(15,5))
sns.barplot(h3.index,h3)
#More registered user take bike during morning 8 o clock and from evening 4 to 6
# Out:
# hr
# 0      31755
# 1      19455
# 2      12940
# 3       6281
# 4       3554
# 5      13249
# 6      52115
# 7     146134
# 8     245240
# 9     136980
# 10     92468
# 11    108034
# 12    134696
# 13    132206
# 14    120563
# 15    128543
# 16    173914
# 17    282640
# 18    265276
# 19    191284
# 20    138172
# 21    104875
# 22     79412
# 23     52876
# Name: registered, dtype: int64

# %% [markdown]
# # Season

# %%
spring=df[df['season']==1].shape
summer=df[df['season']==2].shape
fall=df[df['season']==3].shape
winter=df[df['season']==4].shape
print(spring)
print(summer)
print(fall)
print(winter)

s=df.groupby('season')['cnt'].sum()
print(s)
plt.figure(figsize=(15,5))
sns.barplot(s.index,s)
#More people are taking bikes for rent during summer and fall
# Out:
# (4242, 16)
# (4409, 16)
# (4496, 16)
# (4232, 16)
# season
# 1     471348
# 2     918589
# 3    1061129
# 4     841613
# Name: cnt, dtype: int64

# %% [markdown]
# # Holidays

# %%
h=df['holiday'].value_counts()
print(h)
# Out:
# 0    16879
# 1      500
# Name: holiday, dtype: int64

# %%
group1=df[df['holiday']==0]
group2=df[df['holiday']==1]
print(group1.shape)
print(group2.shape)

group1_resample=group1.sample(n=500)

holiday=pd.concat([group1_resample,group2])
print(holiday.shape)
holiday
# Out:
# (16879, 16)
# (500, 16)
# (1000, 16)
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 13772    2012-08-02       3   1     8   0        0        4           1
# 15749    2012-10-23       4   1    10   9        0        2           1
# 14108    2012-08-16       3   1     8   0        0        4           1
# 16987    2012-12-15       4   1    12  13        0        6           0
# 3130     2011-05-15       2   0     5   7        0        0           0
# 17270    2012-12-27       1   1    12  10        0        4           1
# 8164     2011-12-11       4   0    12  19        0        0           0
# 16174    2012-11-11       4   1    11  15        0        0           0
# 6486     2011-10-02       4   0    10  19        0        0           0
# 5903     2011-09-08       3   0     9  11        0        4           1
# 2848     2011-05-03       2   0     5  13        0        2           1
# ...

# %%
h=holiday.groupby('holiday')['cnt'].sum()
print(h)
plt.figure(figsize=(6,5))
sns.barplot(h.index,h)
#Bike rental is slightly higher in week days than holidays
# Out:
# holiday
# 0    93282
# 1    78435
# Name: cnt, dtype: int64

# %%
#H0: Two mean are same
#H1: Two mean are different
# mannwhitneyu test is used because data is not normally distributed
from scipy.stats import ttest_ind,f_oneway,mannwhitneyu,kruskal
g1=group1_resample['cnt']
g2=group2['cnt']

t_statistic, p_value = mannwhitneyu(g1, g2)
print(t_statistic, p_value)
#Since p value is <0.05 we reject null hypothesis and therefore two means are different
# Out:
# 114674.5 0.011879356721589749

# %% [markdown]
# # Week day

# %%
df.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1

# %%
w=df['weekday'].value_counts()
w
# Out:
# 6    2512
# 0    2502
# 5    2487
# 1    2479
# 3    2475
# 4    2471
# 2    2453
# Name: weekday, dtype: int64

# %%
week=df.groupby('weekday')['cnt'].sum()
print(week)
plt.figure(figsize=(15,5))
sns.barplot(week.index,week)
#Bike sharing count is almost equal on all days
# Out:
# weekday
# 0    444027
# 1    455503
# 2    469109
# 3    473048
# 4    485395
# 5    487790
# 6    477807
# Name: cnt, dtype: int64

# %%
week_sampling=df.sample(n=4000)
g1=week_sampling[week_sampling['weekday']==0]
g2=week_sampling[week_sampling['weekday']==1]
g3=week_sampling[week_sampling['weekday']==2]
g4=week_sampling[week_sampling['weekday']==3]
g5=week_sampling[week_sampling['weekday']==4]
g6=week_sampling[week_sampling['weekday']==5]
g7=week_sampling[week_sampling['weekday']==6]

# %%
#Since data is not normal kruskal test is used instead of ANOVA
#H0: Mean is equal across all groups
#H1: Atleast one of the mean significantly varies
kruskal(g1['cnt'],g2['cnt'],g3['cnt'],g4['cnt'],g5['cnt'],g6['cnt'],g7['cnt'])
#Since p value is >0.05 we do not reject null hypothesis
# Out:
# KruskalResult(statistic=9.040650335382638, pvalue=0.17130479894971923)

# %% [markdown]
# # Working day

# %%
working_day=df.groupby('workingday')['cnt'].sum()
print(working_day)
plt.figure(figsize=(5,5))
sns.barplot(working_day.index,working_day)
# Out:
# workingday
# 0    1000269
# 1    2292410
# Name: cnt, dtype: int64

# %%
working_day=df.sample(n=4000)
g1=working_day[working_day['workingday']==0]
g2=working_day[working_day['workingday']==1]

# %%
#H0:Two means are equal
#H1:Two means are different
mannwhitneyu(g1['cnt'],g2['cnt'])
#Since p value is > 0.05 we do not reject the null hypothesis and therefore two sample means are equal
# Out:
# MannwhitneyuResult(statistic=1663203.5, pvalue=0.2995889026215738)

# %% [markdown]
# # Weather

# %%
weather=df.groupby('weathersit')['cnt'].sum()
print(weather)
plt.figure(figsize=(10,5))
sns.barplot(weather.index,weather)
#When the sky is clear more people take bike for rent which is followed by partly cloudy, mist and heavy rain
# Out:
# weathersit
# 1    2338173
# 2     795952
# 3     158331
# 4        223
# Name: cnt, dtype: int64

# %% [markdown]
# # Temperature

# %%
df1=df.copy()
df1.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df1['temperature']=47*df1['temp']-8
df1.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1
#
#          temperature
# instant
# 1               3.28
# ...

# %%
df1['actual_temperature']=66*df1['atemp']-16
df1.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1
#
#          temperature  actual_temperature
# instant
# ...

# %%
df1['temperature'].corr(df['cnt'])
# Out:
# 0.40477227577865876

# %%
plt.scatter(df1['temperature'],df1['cnt'])
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df1,hue='season',size=6).map(sns.distplot,'temperature').add_legend()
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x='season',y='temperature',data=df1)
plt.show()

# %% [markdown]
# # Humidity

# %%
df1['hum'].corr(df1['cnt'])
#Negative correlation is present. Therefore when humidity increases count decreases
# Out:
# -0.32291074082456045

# %%
plt.scatter(df1['hum'],df1['cnt'])
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df1,hue='season',size=6).map(sns.distplot,'hum').add_legend()
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x='season',y='hum',data=df1)
plt.show()

# %% [markdown]
# # Wind speed

# %%
df1['windspeed'].corr(df1['cnt'])
#very week correlation
# Out:
# 0.09323378392612534

# %%
plt.scatter(df1['windspeed'],df1['cnt'])
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df1,hue='season',size=6).map(sns.distplot,'windspeed').add_legend()
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
